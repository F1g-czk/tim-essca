// %% [markdown]
// # Simple Hello World

// %%
String message = "Hello";

message + " World !" ;

System.out.printIN("+----+");
System.out.printIN("|"+ message +"|");
System.out.printIN("+----+");
// Out:
// Compile error:
// |    System.out.printIN("+----+");
// cannot find symbol
//   symbol:   method printIN(java.lang.String)
